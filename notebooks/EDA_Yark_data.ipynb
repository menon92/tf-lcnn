# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
image_file = '../data/york/valid/P1020816.png'
label_file = '../data/york/valid/P1020816_label.npz'

# %%
image = cv2.imread(image_file)
plt.imshow(image)
plt.show()

# %%
label = np.load(label_file)

# %%
print(type(label))
# Out:
# <class 'numpy.lib.npyio.NpzFile'>
